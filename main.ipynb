# %% [markdown]
# # Heat Islant Detection Using CNN

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# Out:
# 2024-12-02 21:03:40.730946: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-02 21:03:40.754261: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-02 21:03:40.761350: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-02 21:03:40.778922: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# x_batches = [np.load(f'X_batch_{i}_{i+1000}.npy') for i in range(0, 2000, 1000)]
# y_batches = [np.load(f'y_batch_thermal_{i}_{i+1000}.npy') for i in range(0, 2000, 1000)]



# # Combine all batches into a single array for X and y
# x = np.concatenate(x_batches, axis=0)
# y = np.concatenate(y_batches, axis=0)

# %%
x = np.load('X_batch_2000_3000.npy')
y =  np.load('y_batch_thermal_2000_3000.npy')

# %%
x.shape
# Out:
# (1000, 13, 288, 288)

# %%
y.shape
# Out:
# (1000, 5, 288, 288)

# %%
# lets pick and plot image 100

# %%
# lidar Return Count - Max
plt.imshow(x[100,1,::])
plt.colorbar()

# %%
# the negative values there were becuase of -9999 nan values. lets fix it
plt.imshow(x[100,1,::],  vmin=0, vmax=4000)
plt.colorbar()

# %%
# lets plot x and y and try to see heat island

# %%
# plot elevation mean
plt.imshow(x[500,6,::])
plt.colorbar()

# %%
plt.imshow(y[500,1,::])
plt.colorbar()

# %%
#why left side is colder than right? doenst make much sense

# %%
#***** let's select the needed layers from dataset since we will not work with all of them

# %%
x = x[:, :-1, :, :]  # exclude last layers with different value range

y = y[:, :-2, :, :] #exclude last 2 layers

# %%
# check shapes  
print(x.shape, y.shape)
# Out:
# (1000, 12, 288, 288) (1000, 3, 288, 288)

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /srv/conda/envs/notebook/lib/python3.12/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from opencv-python) (1.26.4)

# %%
# ************ 1st interpolation try: complex, old code
import cv2


def fill_missing_with_inpaint(X, no_data_values):
    """
    Fill missing values in a 4D array (loc, layer, n, m) using OpenCV inpainting.

    Parameters:
        X (numpy.ndarray): Input data array with shape (loc, layer, n, m).
        no_data_values (list): List of no-data placeholder values to fill.

    Returns:
        numpy.ndarray: Array with missing values filled.
    """
    X_filled = X.copy()
    for loc in range(X.shape[0]):
        for layer in range(X.shape[1]):
            # Create a mask where missing values are marked
            mask = np.isin(X[loc, layer, :, :], no_data_values).astype(np.uint8)
            # Use inpainting to fill the missing values
            X_filled[loc, layer, :, :] = cv2.inpaint(
                X[loc, layer, :, :].astype(np.float32),  # Input image
                mask,  # Mask indicating missing values
                inpaintRadius=3,  # Radius for inpainting
                flags=cv2.INPAINT_TELEA  # Inpainting algorithm
            )
    return X_filled

# %%
# ***** do interpolation
no_data_values = [-9999]
x_filled = fill_missing_with_inpaint(x, no_data_values)

# %%
x_filled.shape
# Out:
# (1000, 12, 288, 288)

# %%
# lets see how it behaves

# %%
# before interpolation
plt.imshow(x[100,1,::])
plt.colorbar()

# %%
# before interpolation - fixed bars
plt.imshow(x[100,1,::], vmin=1000, vmax = 5000)
plt.colorbar()

# %%
# after interpolation
plt.imshow(x_filled[100,1,::])
plt.colorbar()

# %%
## another example
plt.imshow(x[700,1,::])
plt.colorbar()

# %%
plt.imshow(x_filled[700,1,::])
plt.colorbar()

# %%
plt.imshow(x[700,1,::], vmin = 1000, vmax = 6000)
plt.colorbar()

# %%
## lets see pixel values in histograms

# %%
# plt.hist(x_filled[700,1,::])

# %%
# plt.hist(x[700,1,::], range=(1000, 6000))

# %%
# **************** now lets prepare training dataset *********************#

# %% [markdown]
# ### X train

# %%
# Transpose X_filled to match TensorFlow's input shape (batch_size, height, width, channels)
x_train = x_filled.transpose(0, 2, 3, 1)  # Shape becomes (1000, 288, 288, 13)
x_train.shape
# Out:
# (1000, 288, 288, 12)

# %% [markdown]
# ### y train

# %%
y[0]
# Out:
# array([[[3035, 3035, 3035, ..., 3051, 3051, 3051],
#         [3035, 3035, 3035, ..., 3051, 3051, 3051],
#         [3035, 3035, 3035, ..., 3051, 3051, 3051],
#         ...,
#         [2960, 2960, 2960, ..., 2998, 2998, 2998],
#         [2960, 2960, 2960, ..., 2998, 2998, 2998],
#         [2960, 2960, 2960, ..., 2998, 2998, 2998]],
#
#        [[3218, 3218, 3218, ..., 3302, 3302, 3302],
#         [3218, 3218, 3218, ..., 3302, 3302, 3302],
#         [3218, 3218, 3218, ..., 3302, 3302, 3302],
#         ...,
#         [3030, 3030, 3030, ..., 3158, 3158, 3158],
#         [3030, 3030, 3030, ..., 3158, 3158, 3158],
#         [3030, 3030, 3030, ..., 3158, 3158, 3158]],
#
#        [[2948, 2948, 2948, ..., 3018, 3018, 3018],
#         [2948, 2948, 2948, ..., 3018, 3018, 3018],
#         [2948, 2948, 2948, ..., 3018, 3018, 3018],
#         ...,
#         [2798, 2798, 2798, ..., 2907, 2907, 2907],
#         [2798, 2798, 2798, ..., 2907, 2907, 2907],
#         [2798, 2798, 2798, ..., 2907, 2907, 2907]]], dtype=int16)

# %%
y = y/ 100  # convert to celcius

# %%
y[0]
# Out:
# array([[[30.35, 30.35, 30.35, ..., 30.51, 30.51, 30.51],
#         [30.35, 30.35, 30.35, ..., 30.51, 30.51, 30.51],
#         [30.35, 30.35, 30.35, ..., 30.51, 30.51, 30.51],
#         ...,
#         [29.6 , 29.6 , 29.6 , ..., 29.98, 29.98, 29.98],
#         [29.6 , 29.6 , 29.6 , ..., 29.98, 29.98, 29.98],
#         [29.6 , 29.6 , 29.6 , ..., 29.98, 29.98, 29.98]],
#
#        [[32.18, 32.18, 32.18, ..., 33.02, 33.02, 33.02],
#         [32.18, 32.18, 32.18, ..., 33.02, 33.02, 33.02],
#         [32.18, 32.18, 32.18, ..., 33.02, 33.02, 33.02],
#         ...,
#         [30.3 , 30.3 , 30.3 , ..., 31.58, 31.58, 31.58],
#         [30.3 , 30.3 , 30.3 , ..., 31.58, 31.58, 31.58],
#         [30.3 , 30.3 , 30.3 , ..., 31.58, 31.58, 31.58]],
#
#        [[29.48, 29.48, 29.48, ..., 30.18, 30.18, 30.18],
#         [29.48, 29.48, 29.48, ..., 30.18, 30.18, 30.18],
#         [29.48, 29.48, 29.48, ..., 30.18, 30.18, 30.18],
#         ...,
#         [27.98, 27.98, 27.98, ..., 29.07, 29.07, 29.07],
#         [27.98, 27.98, 27.98, ..., 29.07, 29.07, 29.07],
#         [27.98, 27.98, 27.98, ..., 29.07, 29.07, 29.07]]])

# %%
y.shape
# Out:
# (1000, 3, 288, 288)

# %%
# lets convert y into mean and stdev labels

means = np.mean(y.reshape(1000, -1), axis=1)  # Shape: (1000,)
stds = np.std(y.reshape(1000, -1), axis=1)   # Shape: (1000,)

# %%
means.shape
# Out:
# (1000,)

# %%
# check calculations of mean and stdev
means[10]
# Out:
# 32.03482486175411

# %%
np.mean(y[10])
# Out:
# 32.03482486175411

# %%
stds[10]
# Out:
# 1.2118705957412377

# %%
np.std(y[10])
# Out:
# 1.2118705957412377

# %%
# all is fine

# %%
mean_std = np.stack((means, stds), axis=1)

# %%
mean_std
# Out:
# array([[30.71710512,  1.2203216 ],
#        [30.35156925,  1.06688589],
#        [30.92110765,  1.25441505],
#        ...,
#        [28.93565325,  1.27512289],
#        [27.63625197,  1.24895214],
#        [28.93737771,  1.35481556]])

# %%
y_train = mean_std

# %%
y_train.shape
# Out:
# (1000, 2)

# %% [markdown]
# ## Train CNN Model

# %%
import tensorflow as tf

# Define input layer with the updated shape
inputs = tf.keras.layers.Input(shape=(288, 288, 12))

# Contracting Path - Encoder
c1 = tf.keras.layers.Conv2D(16, (3, 3), kernel_initializer='he_normal', padding='same')(inputs)
c1 = tf.keras.layers.BatchNormalization()(c1)  # Batch Normalization
c1 = tf.keras.layers.Activation('relu')(c1)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(16, (3, 3), kernel_initializer='he_normal', padding='same')(c1)
c1 = tf.keras.layers.BatchNormalization()(c1)  # Batch Normalization
c1 = tf.keras.layers.Activation('relu')(c1)
p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

c2 = tf.keras.layers.Conv2D(32, (3, 3), kernel_initializer='he_normal', padding='same')(p1)
c2 = tf.keras.layers.BatchNormalization()(c2)  # Batch Normalization
c2 = tf.keras.layers.Activation('relu')(c2)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(32, (3, 3), kernel_initializer='he_normal', padding='same')(c2)
c2 = tf.keras.layers.BatchNormalization()(c2)  # Batch Normalization
c2 = tf.keras.layers.Activation('relu')(c2)
p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)


#bottleneck
c3 = tf.keras.layers.Conv2D(64, (3, 3), kernel_initializer='he_normal', padding='same')(p2)
c3 = tf.keras.layers.BatchNormalization()(c3)  # Batch Normalization
c3 = tf.keras.layers.Activation('relu')(c3)
c3 = tf.keras.layers.Dropout(0.2)(c3)
c3 = tf.keras.layers.Conv2D(64, (3, 3), kernel_initializer='he_normal', padding='same')(c3)
c3 = tf.keras.layers.BatchNormalization()(c3)  # Batch Normalization
c3 = tf.keras.layers.Activation('relu')(c3)
p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)

# Bottleneck
c4 = tf.keras.layers.Conv2D(64, (3, 3), kernel_initializer='he_normal', padding='same')(p3)
c4 = tf.keras.layers.BatchNormalization()(c4)  # Batch Normalization
c4 = tf.keras.layers.Activation('relu')(c4)
c4 = tf.keras.layers.Dropout(0.3)(c4)
c4 = tf.keras.layers.Conv2D(64, (3, 3), kernel_initializer='he_normal', padding='same')(c4)
c4 = tf.keras.layers.BatchNormalization()(c4)  # Batch Normalization
c4 = tf.keras.layers.Activation('relu')(c4)


flattened = tf.keras.layers.GlobalAveragePooling2D()(c4)  # Flatten bottleneck feature maps

# first dense layer
dense1 = tf.keras.layers.Dense(64, kernel_initializer='he_normal')(flattened)
dense1 = tf.keras.layers.BatchNormalization()(dense1)  # Batch Normalization
dense1 = tf.keras.layers.Activation('relu')(dense1)


# second dense layer
dense2 = tf.keras.layers.Dense(32, kernel_initializer='he_normal')(dense1)
dense2 = tf.keras.layers.BatchNormalization()(dense2)  # Batch Normalization
dense2 = tf.keras.layers.Activation('relu')(dense2)

outputs = tf.keras.layers.Dense(2, activation='linear')(dense2)  # Predict mean and stdev

# Create and compile the model
model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='mse', metrics=['mae'])  # Mean Squared Error for regression


# callbacks
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='best_model_with_early_stopping_last.keras.keras',  # Filepath to save the model
    monitor='val_loss',          # Monitor validation loss
    save_best_only=True,         # Save only the best model
    save_weights_only=False,     # Save the entire model
    mode='min',                  # Minimize the validation loss
    verbose=1                    # Print updates during training
)

# Define the EarlyStopping callback
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',         # Monitor validation loss
    patience=10,                # Stop after 10 epochs with no improvement
    restore_best_weights=True,  # Restore the best weights after stopping
    mode='min',                 # Minimize the validation loss
    verbose=1                   # Print when stopping
)

# Train the model
history = model.fit(
    x_train,           # Input data (12-channel LiDAR images)
    y_train,          # Labels (mean and standard deviation vectors)
    validation_split=0.2,
    batch_size= 16,
    epochs=50,
    callbacks=[checkpoint_callback, early_stopping_callback]
)

# Save the model
model.save('best_model_with_early_stopping_last.keras')
# Out:
# 2024-12-02 21:14:33.230969: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1592524800 exceeds 10% of free system memory.
# Epoch 1/50
# /srv/conda/envs/notebook/lib/python3.12/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_166']. Received: the structure of inputs=*
#   warnings.warn(
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 332.2743 - mae: 13.4892
# Epoch 1: val_loss improved from inf to 330.28848, saving model to best_model_with_early_stopping_last.keras.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 21s 138ms/step - loss: 332.2561 - mae: 13.4880 - val_loss: 330.2885 - val_mae: 13.0340
# Epoch 2/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 305.1490 - mae: 12.7037
# Epoch 2: val_loss improved from 330.28848 to 318.74991, saving model to best_model_with_early_stopping_last.keras.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 305.0287 - mae: 12.7004 - val_loss: 318.7499 - val_mae: 13.3527
# Epoch 3/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 273.9172 - mae: 11.8970
# Epoch 3: val_loss improved from 318.74991 to 269.10123, saving model to best_model_with_early_stopping_last.keras.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 273.8257 - mae: 11.8943 - val_loss: 269.1012 - val_mae: 11.8393
# Epoch 4/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 246.4019 - mae: 11.1692
# Epoch 4: val_loss improved from 269.10123 to 249.01897, saving model to best_model_with_early_stopping_last.keras.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 246.2325 - mae: 11.1653 - val_loss: 249.0190 - val_mae: 11.3601
# Epoch 5/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 211.5243 - mae: 10.3476
# Epoch 5: val_loss improved from 249.01897 to 211.45401, saving model to best_model_with_early_stopping_last.keras.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 211.3994 - mae: 10.3447 - val_loss: 211.4540 - val_mae: 10.4928
# Epoch 6/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 177.5268 - mae: 9.4900
# Epoch 6: val_loss improved from 211.45401 to 171.88817, saving model to best_model_with_early_stopping_last.keras.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 177.3507 - mae: 9.4852 - val_loss: 171.8882 - val_mae: 9.4358
# Epoch 7/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 143.3735 - mae: 8.5265
# Epoch 7: val_loss improved from 171.88817 to 148.22794, saving model to best_model_with_early_stopping_last.keras.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 143.1637 - mae: 8.5201 - val_loss: 148.2279 - val_mae: 8.6564
# Epoch 8/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 110.2033 - mae: 7.4707
# Epoch 8: val_loss improved from 148.22794 to 89.99857, saving model to best_model_with_early_stopping_last.keras.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - loss: 110.0286 - mae: 7.4643 - val_loss: 89.9986 - val_mae: 6.7735
# Epoch 9/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 82.4823 - mae: 6.4254
# Epoch 9: val_loss improved from 89.99857 to 54.30474, saving model to best_model_with_early_stopping_last.keras.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 82.2950 - mae: 6.4178 - val_loss: 54.3047 - val_mae: 5.3489
# Epoch 10/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 52.8615 - mae: 5.1545
# Epoch 10: val_loss improved from 54.30474 to 46.28471, saving model to best_model_with_early_stopping_last.keras.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - loss: 52.7939 - mae: 5.1508 - val_loss: 46.2847 - val_mae: 4.9732
# Epoch 11/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 36.2902 - mae: 4.2456
# Epoch 11: val_loss did not improve from 46.28471
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 36.2190 - mae: 4.2407 - val_loss: 46.7060 - val_mae: 4.8812
# Epoch 12/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 22.6398 - mae: 3.3226
# Epoch 12: val_loss improved from 46.28471 to 32.19624, saving model to best_model_with_early_stopping_last.keras.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 22.5808 - mae: 3.3177 - val_loss: 32.1962 - val_mae: 4.0279
# Epoch 13/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 12.5626 - mae: 2.4281
# Epoch 13: val_loss improved from 32.19624 to 21.33410, saving model to best_model_with_early_stopping_last.keras.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 12.5420 - mae: 2.4260 - val_loss: 21.3341 - val_mae: 3.2043
# Epoch 14/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 8.5575 - mae: 1.9596
# Epoch 14: val_loss improved from 21.33410 to 14.68327, saving model to best_model_with_early_stopping_last.keras.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 8.5237 - mae: 1.9550 - val_loss: 14.6833 - val_mae: 2.7148
# Epoch 15/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 4.3488 - mae: 1.3883
# Epoch 15: val_loss improved from 14.68327 to 2.72370, saving model to best_model_with_early_stopping_last.keras.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 4.3398 - mae: 1.3863 - val_loss: 2.7237 - val_mae: 1.0279
# Epoch 16/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 2.5636 - mae: 1.0259
# Epoch 16: val_loss improved from 2.72370 to 2.39908, saving model to best_model_with_early_stopping_last.keras.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - loss: 2.5608 - mae: 1.0253 - val_loss: 2.3991 - val_mae: 0.9664
# Epoch 17/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.9023 - mae: 0.8825
# Epoch 17: val_loss improved from 2.39908 to 2.15040, saving model to best_model_with_early_stopping_last.keras.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 1.9035 - mae: 0.8827 - val_loss: 2.1504 - val_mae: 0.9298
# Epoch 18/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.9170 - mae: 0.8819
# Epoch 18: val_loss did not improve from 2.15040
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 1.9155 - mae: 0.8817 - val_loss: 2.8032 - val_mae: 1.1327
# Epoch 19/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.9083 - mae: 0.8026
# Epoch 19: val_loss improved from 2.15040 to 1.18739, saving model to best_model_with_early_stopping_last.keras.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 1.9018 - mae: 0.8021 - val_loss: 1.1874 - val_mae: 0.6953
# Epoch 20/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.5081 - mae: 0.7881
# Epoch 20: val_loss did not improve from 1.18739
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 1.5065 - mae: 0.7876 - val_loss: 1.4862 - val_mae: 0.7831
# Epoch 21/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.1288 - mae: 0.6697
# Epoch 21: val_loss did not improve from 1.18739
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 1.1285 - mae: 0.6694 - val_loss: 1.6528 - val_mae: 0.8524
# Epoch 22/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.0752 - mae: 0.6607
# Epoch 22: val_loss did not improve from 1.18739
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 1.0754 - mae: 0.6609 - val_loss: 1.2131 - val_mae: 0.7227
# Epoch 23/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.9962 - mae: 0.6387
# Epoch 23: val_loss improved from 1.18739 to 1.17711, saving model to best_model_with_early_stopping_last.keras.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 0.9976 - mae: 0.6392 - val_loss: 1.1771 - val_mae: 0.7519
# Epoch 24/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.3566 - mae: 0.7074
# Epoch 24: val_loss did not improve from 1.17711
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 1.3515 - mae: 0.7067 - val_loss: 2.0498 - val_mae: 0.9518
# Epoch 25/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.2926 - mae: 0.7223
# Epoch 25: val_loss did not improve from 1.17711
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 1.2936 - mae: 0.7226 - val_loss: 1.7224 - val_mae: 0.8793
# Epoch 26/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.2947 - mae: 0.7239
# Epoch 26: val_loss did not improve from 1.17711
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 1.2950 - mae: 0.7240 - val_loss: 2.2562 - val_mae: 1.0141
# Epoch 27/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.4410 - mae: 0.7709
# Epoch 27: val_loss did not improve from 1.17711
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 1.4396 - mae: 0.7703 - val_loss: 2.1028 - val_mae: 0.9590
# Epoch 28/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.1627 - mae: 0.6801
# Epoch 28: val_loss did not improve from 1.17711
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 1.1651 - mae: 0.6808 - val_loss: 1.4675 - val_mae: 0.8307
# Epoch 29/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.1601 - mae: 0.6817
# Epoch 29: val_loss did not improve from 1.17711
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 1.1594 - mae: 0.6815 - val_loss: 1.5717 - val_mae: 0.8595
# Epoch 30/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.1453 - mae: 0.6858
# Epoch 30: val_loss did not improve from 1.17711
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 1.1439 - mae: 0.6855 - val_loss: 1.4796 - val_mae: 0.8130
# Epoch 31/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.2390 - mae: 0.6885
# Epoch 31: val_loss did not improve from 1.17711
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 1.2414 - mae: 0.6889 - val_loss: 1.8307 - val_mae: 0.9075
# Epoch 32/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.9977 - mae: 0.6522
# Epoch 32: val_loss did not improve from 1.17711
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 0.9970 - mae: 0.6519 - val_loss: 1.5756 - val_mae: 0.8394
# Epoch 33/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.7708 - mae: 0.5553
# Epoch 33: val_loss improved from 1.17711 to 0.91674, saving model to best_model_with_early_stopping_last.keras.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - loss: 0.7733 - mae: 0.5563 - val_loss: 0.9167 - val_mae: 0.6291
# Epoch 34/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.9352 - mae: 0.6309
# Epoch 34: val_loss did not improve from 0.91674
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 0.9365 - mae: 0.6312 - val_loss: 1.4457 - val_mae: 0.7484
# Epoch 35/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.3704 - mae: 0.7023
# Epoch 35: val_loss did not improve from 0.91674
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 1.3666 - mae: 0.7017 - val_loss: 2.1646 - val_mae: 1.0201
# Epoch 36/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.2353 - mae: 0.7152
# Epoch 36: val_loss did not improve from 0.91674
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 1.2308 - mae: 0.7138 - val_loss: 1.2980 - val_mae: 0.7642
# Epoch 37/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.8121 - mae: 0.5798
# Epoch 37: val_loss did not improve from 0.91674
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 0.8139 - mae: 0.5803 - val_loss: 1.5342 - val_mae: 0.7990
# Epoch 38/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.8081 - mae: 0.5929
# Epoch 38: val_loss did not improve from 0.91674
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 0.8095 - mae: 0.5933 - val_loss: 1.4850 - val_mae: 0.8857
# Epoch 39/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.3270 - mae: 0.6916
# Epoch 39: val_loss did not improve from 0.91674
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 1.3280 - mae: 0.6920 - val_loss: 1.5296 - val_mae: 0.8065
# Epoch 40/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.0454 - mae: 0.6341
# Epoch 40: val_loss did not improve from 0.91674
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 1.0453 - mae: 0.6342 - val_loss: 1.0516 - val_mae: 0.7107
# Epoch 41/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.9435 - mae: 0.6202
# Epoch 41: val_loss did not improve from 0.91674
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 0.9484 - mae: 0.6216 - val_loss: 1.5714 - val_mae: 0.8780
# Epoch 42/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.9191 - mae: 0.6224
# Epoch 42: val_loss did not improve from 0.91674
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 0.9203 - mae: 0.6228 - val_loss: 1.2510 - val_mae: 0.7585
# Epoch 43/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.0478 - mae: 0.6476
# Epoch 43: val_loss did not improve from 0.91674
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 1.0496 - mae: 0.6482 - val_loss: 1.6436 - val_mae: 0.8335
# Epoch 43: early stopping
# Restoring model weights from the end of the best epoch: 33.

# %%
# load the model
model_path = 'best_model_with_early_stopping_modified.keras'
loaded_model = tf.keras.models.load_model(model_path)

# %%
# Extract metrics from the training history
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_mae = history.history['mae']
val_mae = history.history['val_mae']

# Plot Training and Validation Loss
plt.figure(figsize=(8, 6))
plt.plot(train_loss, label='Training Loss', linestyle='--', marker='o')
plt.plot(val_loss, label='Validation Loss', linestyle='-', marker='x')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)


plt.savefig('simple_thermal_unet_model_with_interpolation.keras.loss.png', dpi=300, bbox_inches='tight')

# %%
# Plot Training and Validation MAE
plt.figure(figsize=(8, 6))
plt.plot(train_mae, label='Training MAE', linestyle='--', marker='o')
plt.plot(val_mae, label='Validation MAE', linestyle='-', marker='x')
plt.title('Model MAE Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Mean Absolute Error (MAE)')
plt.legend()
plt.grid(True)


plt.savefig('simple_thermal_unet_model_with_interpolation.keras.mae.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### Predictions on train data

# %%
# Select one sample

sample_idx = 100  # Index of the sample to evaluate
x_sample = x_train[sample_idx]  # Shape: (13, 288, 288)
y_original = mean_std[sample_idx]  # Shape: (288, 288)

plt.imshow(x_train[sample_idx,:,:, 1])
plt.colorbar()

# %%
# Run the sample through the model to get predictions
total = 10
errors = []
results = []
for sample_idx in range(0, total):
    
    x_sample  = x_train[sample_idx]
    x_sample = np.expand_dims(x_sample, axis=0)  # Add batch dimension (1, 13, 288, 288)
    predicted = model.predict(x_sample)  # Output shape: (1, 288, 288, 1)
    predicted = predicted.squeeze()  # Remove extra dimensions, shape becomes (288, 288)
    original = mean_std[sample_idx]
    # print(predicted - 
    # print(mean_std[sample_idx])
    errors.append((predicted - mean_std[sample_idx])**2 )
    results.append([predicted, original])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %%
results
# Out:
# [[array([29.725039 ,  1.2975105], dtype=float32),
#   array([20.8714349 ,  0.78682991])],
#  [array([28.32448  ,  1.2193124], dtype=float32),
#   array([24.37828836,  0.53649119])],
#  [array([29.214636 ,  1.2336998], dtype=float32),
#   array([23.82496902,  0.70312288])],
#  [array([28.031746 ,  1.1565845], dtype=float32),
#   array([22.60774587,  0.69518479])],
#  [array([28.804285 ,  1.2113075], dtype=float32),
#   array([21.46310298,  0.78826041])],
#  [array([29.375122 ,  1.2860117], dtype=float32),
#   array([25.59554475,  0.42979377])],
#  [array([29.48169,  1.2774 ], dtype=float32),
#   array([25.45946398,  0.53783799])],
#  [array([29.152859 ,  1.2093885], dtype=float32),
#   array([24.6664597 ,  0.87421719])],
#  [array([29.215477 ,  1.2532114], dtype=float32),
#   array([24.11838389,  0.83630458])],
#  [array([29.365984 ,  1.2710664], dtype=float32),
#   array([26.90701212,  0.98188753])]]

# %% [markdown]
# ## Run Inference

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
x = np.load('X_batch_1000_2000.npy')
y =  np.load('y_batch_thermal_1000_2000.npy')


x = x[:, :-1, :, :]  # exclude last layers with different value range

y = y[:, :-2, :, :]

no_data_values = [-9999]
x_filled = fill_missing_with_inpaint(x, no_data_values)
x_test = x_filled.transpose(0, 2, 3, 1)

y = y/ 100  # convert to celcius

means = np.mean(y.reshape(1000, -1), axis=1)  # Shape: (1000,)
stds = np.std(y.reshape(1000, -1), axis=1)   # Shape: (1000,)
mean_std = np.stack((means, stds), axis=1)

y_test = mean_std

# %%
# !pip install visualkeras
# Out:
# Collecting visualkeras
#   Using cached visualkeras-0.1.4-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pillow>=6.2.0 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from visualkeras) (11.0.0)
# Requirement already satisfied: numpy>=1.18.1 in /srv/conda/envs/notebook/lib/python3.12/site-packages (from visualkeras) (1.26.4)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Using cached aggdraw-1.3.19-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (655 bytes)
# Using cached visualkeras-0.1.4-py3-none-any.whl (17 kB)
# Using cached aggdraw-1.3.19-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.19 visualkeras-0.1.4

# %%
plt.imshow(x_test[0,:,:,6])

# %%
import visualkeras

img = visualkeras.layered_view(
    model, 
    scale_xy=0.5,  # Scale the x and y dimensions of the layers
    scale_z=0.5,
    legend=True)

img.save("model_visualization.png")

# %%
total = 100
predicted_means = []
original_means = []
predicted_stds = []
original_stds = []

# Loop over the test dataset
for sample_idx in range(0, total):
    # Get a single test sample (shape: (288, 288, 12) for LiDAR data)
    x_sample = x_test[sample_idx]
    x_sample = np.expand_dims(x_sample, axis=0)  # Add batch dimension (1, 288, 288, 12)
    
    # Run the model to predict mean and std for the current sample
    predicted = model.predict(x_sample)  # Output shape: (1, 2) -> [mean, std]
    predicted = predicted.squeeze()  # Remove batch dimension, shape becomes (2,)
    
    # Get the original mean and std from y_test
    original = y_test[sample_idx]  # Shape: (2,)
    
    # Store the predicted and original values for plotting
    predicted_means.append(predicted[0])
    predicted_stds.append(predicted[1])
    original_means.append(original[0])
    original_stds.append(original[1])

# Convert lists to NumPy arrays for easier plotting
predicted_means = np.array(predicted_means)
predicted_stds = np.array(predicted_stds)
original_means = np.array(original_means)
original_stds = np.array(original_stds)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt

# Calculate limits dynamically with a margin
mean_margin = 0.1 * (max(original_means) - min(original_means))
mean_xlim = [min(original_means) - mean_margin, max(original_means) + mean_margin]

std_margin = 0.1 * (max(original_stds) - min(original_stds))
std_xlim = [min(original_stds) - std_margin, max(original_stds) + std_margin]

# Scatter Plot for Mean
plt.figure(figsize=(8, 4))

# Mean
plt.subplot(1, 2, 1)
plt.scatter(original_means, predicted_means, c='blue', alpha=0.6, label="Data Points")
plt.plot(mean_xlim, mean_xlim, color='red', linestyle='--', label="Ideal Fit (y=x)")
plt.title("Original vs Predicted Mean")
plt.xlim(mean_xlim)
plt.ylim(mean_xlim)
plt.xlabel("Original Mean Temperature (°C)")
plt.ylabel("Predicted Mean Temperature (°C)")
plt.legend()
plt.grid(alpha=0.3)

# Standard Deviation
plt.subplot(1, 2, 2)
plt.scatter(original_stds, predicted_stds, c='green', alpha=0.6, label="Data Points")
plt.plot(std_xlim, std_xlim, color='red', linestyle='--', label="Ideal Fit (y=x)")
plt.title("Original vs Predicted Std Dev")
plt.xlabel("Original Std Dev (°C)")
plt.ylabel("Predicted Std Dev (°C)")
plt.legend()
plt.grid(alpha=0.3)
plt.xlim(std_xlim)
plt.ylim(std_xlim)

# Show the plots
plt.tight_layout()
plt.savefig("final_regression_plots_optimized.png", dpi=300)
plt.show()

# %%
from scipy.stats import pearsonr


mean_correlations = []
std_correlations = []

# Loop through each LiDAR layer (last dimension in x_test)
for i in range(x_test.shape[-1]):
    # Flatten the LiDAR layer for all samples
    lidar_layer = x_test[:, :, :, i].reshape(x_test.shape[0], -1).mean(axis=1)
    print(lidar_layer.shape)
    # Compute correlation with the mean of the thermal data
    mean_corr, _ = pearsonr(lidar_layer, y_test[:, 0])  # Correlation with mean
   # std_corr, _ = pearsonr(lidar_layer, y_test[:, 1])   # Correlation with std
    
    mean_correlations.append(mean_corr)
    std_correlations.append(std_corr)

# Visualize correlations
plt.figure(figsize=(12, 6))

# Bar plot for mean correlation
plt.subplot(1, 2, 1)
plt.bar(range(1, x_test.shape[-1] + 1), mean_correlations, color='blue', alpha=0.7)
plt.title("Correlation with Thermal Mean")
plt.xlabel("LiDAR Layer")
plt.ylabel("Pearson Correlation")
plt.xticks(range(1, x_test.shape[-1] + 1))
plt.grid()


plt.tight_layout()
plt.savefig("lidar_correlation_analysis.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)
# (1000,)

# %%
#Elevation - Min Elevation - Max Elevation - Mean Elevation - Std correspond to layers 5-8, which show the highest correlation
